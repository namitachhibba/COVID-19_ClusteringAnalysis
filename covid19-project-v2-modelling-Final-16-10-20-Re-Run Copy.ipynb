# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing Libraries</a></span></li><li><span><a href="#Merging-COVID-19-Data-with-INFORM-COVID-19-Risk-Data" data-toc-modified-id="Merging-COVID-19-Data-with-INFORM-COVID-19-Risk-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Merging COVID-19 Data with INFORM COVID-19 Risk Data</a></span></li><li><span><a href="#Visualizing-the-correlation-between-different-variables-in-our-final-dataset-to-be-used-for-modelling" data-toc-modified-id="Visualizing-the-correlation-between-different-variables-in-our-final-dataset-to-be-used-for-modelling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Visualizing the correlation between different variables in our final dataset to be used for modelling</a></span></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Hierarchical-Clustering-on-Principal-Components" data-toc-modified-id="Hierarchical-Clustering-on-Principal-Components-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Hierarchical Clustering on Principal Components</a></span><ul class="toc-item"><li><span><a href="#Defining-Training-Data" data-toc-modified-id="Defining-Training-Data-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Defining Training Data</a></span></li><li><span><a href="#Applying-PCA" data-toc-modified-id="Applying-PCA-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Applying PCA</a></span></li><li><span><a href="#Creating-Dendogram-to-choose-optimal-number-of-clusters" data-toc-modified-id="Creating-Dendogram-to-choose-optimal-number-of-clusters-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Creating Dendogram to choose optimal number of clusters</a></span></li><li><span><a href="#Fitting-Hierarchical-Clustering-to-the-dataset" data-toc-modified-id="Fitting-Hierarchical-Clustering-to-the-dataset-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Fitting Hierarchical Clustering to the dataset</a></span></li><li><span><a href="#Exploring-the-clusters" data-toc-modified-id="Exploring-the-clusters-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Exploring the clusters</a></span></li><li><span><a href="#Summarizing-each-cluster" data-toc-modified-id="Summarizing-each-cluster-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Summarizing each cluster</a></span></li><li><span><a href="#Creating-heatmap-for-the-clusters" data-toc-modified-id="Creating-heatmap-for-the-clusters-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Creating heatmap for the clusters</a></span></li></ul></li><li><span><a href="#Hierarchical-Clustering-on-Self-Organizing-Maps-(SOM)-Nodes" data-toc-modified-id="Hierarchical-Clustering-on-Self-Organizing-Maps-(SOM)-Nodes-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Hierarchical Clustering on Self Organizing Maps (SOM) Nodes</a></span><ul class="toc-item"><li><span><a href="#Creating-Color-palattes-to-be-used-for-Self-Organizing-Maps" data-toc-modified-id="Creating-Color-palattes-to-be-used-for-Self-Organizing-Maps-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Creating Color palattes to be used for Self Organizing Maps</a></span></li><li><span><a href="#Reading-Data" data-toc-modified-id="Reading-Data-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Reading Data</a></span></li><li><span><a href="#Preparing-Training-Data-for-SOM" data-toc-modified-id="Preparing-Training-Data-for-SOM-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Preparing Training Data for SOM</a></span></li><li><span><a href="#Training-SOM" data-toc-modified-id="Training-SOM-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Training SOM</a></span></li><li><span><a href="#Performing-Hierarchical-clustering-on-SOM-nodes" data-toc-modified-id="Performing-Hierarchical-clustering-on-SOM-nodes-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Performing Hierarchical clustering on SOM nodes</a></span></li><li><span><a href="#Plotting-the-clusters-(for-SOM-nodes)" data-toc-modified-id="Plotting-the-clusters-(for-SOM-nodes)-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Plotting the clusters (for SOM nodes)</a></span></li><li><span><a href="#Visualizing-Clusters-and-the-distribution-of-variables-in-them" data-toc-modified-id="Visualizing-Clusters-and-the-distribution-of-variables-in-them-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Visualizing Clusters and the distribution of variables in them</a></span><ul class="toc-item"><li><span><a href="#Visualizing-clusters-and-COVID-19-data-variables-distribution-in-the-clusters" data-toc-modified-id="Visualizing-clusters-and-COVID-19-data-variables-distribution-in-the-clusters-4.2.7.1"><span class="toc-item-num">4.2.7.1&nbsp;&nbsp;</span>Visualizing clusters and COVID-19 data variables distribution in the clusters</a></span></li><li><span><a href="#Visualizing-clusters-and-distribution-of-INFORM-Risk-data-variables-in-the-clusters" data-toc-modified-id="Visualizing-clusters-and-distribution-of-INFORM-Risk-data-variables-in-the-clusters-4.2.7.2"><span class="toc-item-num">4.2.7.2&nbsp;&nbsp;</span>Visualizing clusters and distribution of INFORM Risk data variables in the clusters</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <b> Use This file for report plots and graphs </b>
# <b> The files in this python file are saved, so that any changes in COVID data after today: 16/10/20 do not affect the dendrogram, clustering, heatmaps and SOM heatmaps </b>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
# import os
# os.chdir('/kaggle/working')
# os.getcwd()
# print(os.listdir("../input"))

# %% [markdown]
# ## Merging COVID-19 Data with INFORM COVID-19 Risk Data
# (INFORM COVID-19 Risk Data is already scaled from 0-10)

# %%
df_tails_sc = pd.read_csv("C:/Users/user/Downloads/COVID-19 Related info/df_tails_sc.csv")
df_risk1 = pd.read_csv("C:/Users/user/Downloads/COVID-19 Related info/df_risk1.csv")
df_tails_sc = df_tails_sc.drop('Unnamed: 0', axis = 1)
df_risk1 = df_risk1.drop('Unnamed: 0', axis =1)
df_final = pd.merge(df_tails_sc, df_risk1, on= "Country", how = "inner")
#  df_final.to_csv("C:/Users/user/Downloads/COVID-19 Related info/df_final.csv")
df_final.head()
# Out:
#                Country  Days  CumConfirmed  CumConfirmed_per_million  \
# 0          Afghanistan   215      0.051817                  0.227524
# 1              Albania   219      0.020670                  1.230665
# 2              Algeria   225      0.069425                  0.270739
# 3               Angola   194      0.008868                  0.045615
# 4  Antigua and Barbuda   196      0.000143                  0.253356
#
#    CumDeaths  CumRecovered  smoothed_cumulative_testing_count  \
# 0   0.069086      0.052927                                0.0
# 1   0.020245      0.015490                                0.0
# 2   0.085226      0.059669                                0.0
# 3   0.010589      0.004445                                0.0
# 4   0.000140      0.000159                                0.0
#
#    SmoothedCumTesting_per_thousand  Population  Pop_Density  Land_Area_Kmsq  \
# 0                              0.0    0.270233     0.022024        0.398647
# ...

# %%
df_tails_sc.columns
# df_risk1.head()
# Out:
# Index(['Country', 'Days', 'CumConfirmed', 'CumConfirmed_per_million',
#        'CumDeaths', 'CumRecovered', 'smoothed_cumulative_testing_count',
#        'SmoothedCumTesting_per_thousand', 'Population', 'Pop_Density',
#        'Land_Area_Kmsq', 'HealthCapacityScore', 'RecoveryRate', 'FatalityRate',
#        'Active', 'Population Interval', 'Health Capacity Score Interval'],
#       dtype='object')

# %%
df_final.shape
# Out:
# (179, 49)

# %%
# df_final.columns
df_final = df_final[['Country', 'Days', 'CumConfirmed', 'CumConfirmed_per_million',
       'CumDeaths', 'CumRecovered', 'smoothed_cumulative_testing_count',
       'SmoothedCumTesting_per_thousand', 'Population', 'Pop_Density',
       'Land_Area_Kmsq', 'HealthCapacityScore', 'RecoveryRate', 'FatalityRate',
       'Active', 'P2P', 'P2P_1', 'P2P_2', 'Vul',
       'Vul_HI', 'Vul_1', 'Vul_11', 'Vul_12', 'Vul_13', 'Vul_2', 'Vul_21',
       'Vul_22', 'Vul_23', 'Vul_24', 'Vul_3/Vul_HD', 'Vul_31', 'Vul_32',
       'Vul_33', 'LOCC', 'LOCC_HI', 'LOCC_1', 'LOCC_11', 'LOCC_12', 'LOCC_2',
#        'LOCC_21',
       'LOCC_22', 'LOCC_23', 'LOCC_24', 'LOCC_3/LOCC_HD', 'LOCC_31', 'LOCC_32',
       'INFORM COVID-19 RISK', 'COVID-19 RISK CLASS','Population Interval', 'Health Capacity Score Interval']]
df_final.columns
# Out:
# Index(['Country', 'Days', 'CumConfirmed', 'CumConfirmed_per_million',
#        'CumDeaths', 'CumRecovered', 'smoothed_cumulative_testing_count',
#        'SmoothedCumTesting_per_thousand', 'Population', 'Pop_Density',
#        'Land_Area_Kmsq', 'HealthCapacityScore', 'RecoveryRate', 'FatalityRate',
#        'Active', 'P2P', 'P2P_1', 'P2P_2', 'Vul', 'Vul_HI', 'Vul_1', 'Vul_11',
#        'Vul_12', 'Vul_13', 'Vul_2', 'Vul_21', 'Vul_22', 'Vul_23', 'Vul_24',
#        'Vul_3/Vul_HD', 'Vul_31', 'Vul_32', 'Vul_33', 'LOCC', 'LOCC_HI',
#        'LOCC_1', 'LOCC_11', 'LOCC_12', 'LOCC_2', 'LOCC_22', 'LOCC_23',
#        'LOCC_24', 'LOCC_3/LOCC_HD', 'LOCC_31', 'LOCC_32',
#        'INFORM COVID-19 RISK', 'COVID-19 RISK CLASS', 'Population Interval',
#        'Health Capacity Score Interval'],
#       dtype='object')

# %%
# Making a copy of df_final with Detailed names before applying any modelling technique on it
df_final_renamed = df_final.copy()
df_final_renamed.rename(columns={ 
                'P2P': 'Risk.of.Transmission.from.P2P',
    
                'P2P_1': 'Risk.due2.lack.of.sanitation.and.water.services',
                'P2P_2': 'Risk.based.on.Pop.Dist.', 
                                
                'Vul': 'Vul.Index',
    
                'Vul_HI': 'Hazard.Ind.Vul.Risk.Index',
                'Vul_1':  'INFORM.Socio.Eco.Vul.Risk.Index',
                'Vul_11': 'Vul.related2.Dev.and.Deprivation', 
                'Vul_12': 'Vul.due2.Eco.and.Gender.Inequality',
                'Vul_13': 'Vul.based.on.Eco.Dependency.Index',
                
                'Vul_2':  'INFORM.Vulnerable.Groups.Risk.Index',
                'Vul_21': 'Vul.associated.with.Uprooted.people',
                'Vul_22': 'Vul.due2.other.Health.Condns',
                'Vul_23': 'Vul.due2.lack.of.Food.Security',
                'Vul_24': 'Vul.due2.Gender.Based.Violence',   
    
                'Vul_3/Vul_HD':'Covid19.Overall.Vul.Index',
                'Vul_31': 'Vul.related2.Intl.and.Int.Movements',
                'Vul_32': 'Vul.due2.lackof.authntic.info.nd.trust.on.politicians',
                'Vul_33': 'Vul.due2.1plus.underlying.condns.plus.0.condns.65plus.yrs.pop',                 

                'LOCC': "Lack.of.Coping.Capacity.Index",
                
                'LOCC_HI':'Hazard.Independent.Lack.of.Coping.Capacity.Index',
    
                'LOCC_1': 'INFORM.Risk.Index.related2.Institutional.Strength',
                'LOCC_11': 'Risk.based.on.Corruption.Perception.Index',
                'LOCC_12': 'Risk.based.on.Govt.Effectiveness',
                
                'LOCC_2':'INFORM.Risk.Index.based.on.ltd.opl.Infra',
#                 'LOCC_21':'Risk.based.on.Health system capacity',
                'LOCC_22': 'Risk.associated2.Immunization.coverage',
                'LOCC_23': 'Risk.based.on.pc.public.and.pvt.exp.on.healthcare',
                'LOCC_24': 'Risk.based.on.Maternal.Mortality.ratio',            
                
                'LOCC_3/LOCC_HD': 'Covid19.Overall.Lack.of.coping.capacity.Index',
                'LOCC_31': 'Lack.based.on.IHR.core.capacity.scores',
                'LOCC_32': 'Lack.based.on.Opl.readiness.index',  
    
                'CumConfirmed': 'Cumulative Confirmed Count', 'CumDeaths': 'Cumulative Death Count', 
                'CumRecovered': 'Cumulative Recovered Count',
                'smoothed_cumulative_testing_count': 'Cumulative Testing Count', 
                'CumConfirmed_per_million': 'Cumulative Confirmed per million',
                'SmoothedCumTesting_per_thousand': 'Cumulative Testing per thousand', 
                'Pop_Density': 'Population_Density',
                'Land_Area_Kmsq': 'Land_Area_Kmsq', 
                'HealthCapacityScore': 'Health Capacity Score', 
                'RecoveryRate':'Recovery Rate', 
                'FatalityRate':'Fatality Rate',
                }, inplace = True)

# 'SmoothedCumTesting_per_CumConfirmed': 'Cum Testing per Cum Confirmed Ratio',
# df_final_renamed.to_csv("C:/Users/user/Downloads/COVID-19 Related Info/df_final_renamed1.csv")

# %%
df_final.shape
# Out:
# (179, 49)

# %% [markdown]
# ## Visualizing the correlation between different variables in our final dataset to be used for modelling
# <b> Creating Heatmap </b>

# %%
# df_final.iloc[:, 2:(len(df_final.columns)-4)] = df_final.iloc[:, 2:(len(df_final.columns)-4)].astype(float)
# corrMatrix = df_final.iloc[:, 2:(len(df_final.columns)-4)].corr()
# # print (corrMatrix)
# import seaborn as sn
# import matplotlib.pyplot as plt
# plt.figure(figsize=(30,25)) 
# sn.heatmap(corrMatrix, annot=True)

# plt.show()

# %% [markdown]
# ## Modelling
#
# ### Hierarchical Clustering on Principal Components

# %% [markdown]
# #### Defining Training Data

# %%
df_final.columns
# Out:
# Index(['Country', 'Days', 'CumConfirmed', 'CumConfirmed_per_million',
#        'CumDeaths', 'CumRecovered', 'smoothed_cumulative_testing_count',
#        'SmoothedCumTesting_per_thousand', 'Population', 'Pop_Density',
#        'Land_Area_Kmsq', 'HealthCapacityScore', 'RecoveryRate', 'FatalityRate',
#        'Active', 'P2P', 'P2P_1', 'P2P_2', 'Vul', 'Vul_HI', 'Vul_1', 'Vul_11',
#        'Vul_12', 'Vul_13', 'Vul_2', 'Vul_21', 'Vul_22', 'Vul_23', 'Vul_24',
#        'Vul_3/Vul_HD', 'Vul_31', 'Vul_32', 'Vul_33', 'LOCC', 'LOCC_HI',
#        'LOCC_1', 'LOCC_11', 'LOCC_12', 'LOCC_2', 'LOCC_22', 'LOCC_23',
#        'LOCC_24', 'LOCC_3/LOCC_HD', 'LOCC_31', 'LOCC_32',
#        'INFORM COVID-19 RISK', 'COVID-19 RISK CLASS', 'Population Interval',
#        'Health Capacity Score Interval'],
#       dtype='object')

# %%
X = df_final.iloc[:, 2:(len(df_final. columns)-4)].values
# Leaving Country, Days columns in the beginning and INFORM COVID-19 RISK and COVID-19 RISK CLASS in the end 
X
# Out:
# array([[5.18170027e-02, 2.27524237e-01, 6.90861594e-02, ...,
#         7.00000000e+00, 6.50000000e+00, 7.50000000e+00],
#        [2.06700501e-02, 1.23066507e+00, 2.02453702e-02, ...,
#         5.00000000e+00, 5.00000000e+00, 5.00000000e+00],
#        [6.94253511e-02, 2.70738785e-01, 8.52264776e-02, ...,
#         2.25000000e+00, 2.00000000e+00, 2.50000000e+00],
#        ...,
#        [2.65744831e-03, 1.46404622e-02, 2.78023977e-02, ...,
#         6.15000000e+00, 4.80000000e+00, 7.50000000e+00],
#        [2.01440023e-02, 1.87196278e-01, 1.60936698e-02, ...,
#         7.20000000e+00, 6.90000000e+00, 7.50000000e+00],
#        [1.03771348e-02, 1.19058764e-01, 1.07291132e-02, ...,
#         4.75000000e+00, 4.50000000e+00, 5.00000000e+00]])

# %% [markdown]
# #### Applying PCA
# Since there are lot many correlated variables in our data, it is good to use dimensionality reduction to get more accurate results.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(0.99)
X_new = pca.fit_transform(X)
pca.n_components_
# Out:
# 24

# %%
# <b> To get the two dimensional projection of the data to 2D, we select the number of principal components to be 2</b> <br>
# Looking at the graph we can decide if the classes are well separated using two principal components
# pca = PCA(n_components = 2)
# X_new = pca.fit_transform(X)

# %%
# <b> Variance explained by 2 components </b>
# explained_variance =  pca.explained_variance_ratio_
# np.round(explained_variance,3)
# np.round(sum(explained_variance),3)

# %% [markdown]
# #### Creating Dendogram to choose optimal number of clusters

# %%
# To do this import scipy library (not whole library but the tools it contains to build our dendogram), open source python 
# library that contains tools to do hierarchical clustering and building programs
import scipy.cluster.hierarchy as sch
fig= plt.figure(figsize=(20,10))
# Building Dendogram
dendrogram = sch.dendrogram(sch.linkage(X_new, method = "ward"))
plt.title("Dendrogram")
plt.xlabel("Countries")
plt.ylabel("Euclidean Distances")
plt.savefig('dendrogram final.png')
plt.show()

# sch.dendrogram -> sch is object of class scipy.cluster.hierarchy and dendrogram is method from that class
# linkage is the algorithm of hierarchical clustering
# "ward" method tries to minimize the variance within each cluster
# In kmeans clustering we used to try to minimize "within cluster sum of squares", here in hierarchical clustering we try to 
# minimize "within cluster variance"

# %% [markdown]
# <b> Optimal number of clusters = 4 </b>

# %%
## The dengrogram on 16/10/20 and used for Report
# import os,sys
# from IPython.display import Image
# Image("dendrogram final_fixed.png")


## Cluster order was 3, 1, 2, 0:Later named: B, C, D, A (explanation given later)
## 3: Australia, Germany group; 
## 1: Algeria, India, US group; 
## 2: Albania, Fiji, Vietnam group; 
## 0: Afghanistan, Zimbabwe group

# %% [markdown]
# #### Fitting Hierarchical Clustering to the dataset

# %%
# There are two types of hierarchical clustering:
# 1. Agglomerative Hierarchical clustering
# 2. Divisive Hierarchical clustering

# We will use Agglomerative Hierarchical clustering and the class we are going to use to fit hierarchical clustering to our 
# dataset is agglomerative clustering class from scikit learn library

from sklearn.cluster import AgglomerativeClustering

# Preparing Hierarchical clustering algorithm
hc= AgglomerativeClustering(n_clusters=4, 
                            affinity="euclidean", # affinity stands here for distance
                            linkage="ward") # method to minimize variance in each cluster


# Fitting Hierarchical Clustering algorithm to our data while creating the cluster vector that is the vector that tells for each 
# country which cluster the country belongs to, named y_hc
y_hc = hc.fit_predict(X_new)

# %%
# Adding cluster number to the country which it belongs to according to the results of hierarchical clustering we performed 
# using a new column Cluster_hc
df_final['Cluster_hc'] = y_hc

# %%
## Visualize 2-D projection for the formed clusters
# plt.scatter(x=X_new[y_hc==0, 0], y=X_new[y_hc==0, 1], s=100, c="red", label="Cluster 1" )
# plt.scatter(x=X_new[y_hc==1, 0], y=X_new[y_hc==1, 1], s=100, c="blue", label="Cluster 2" )
# plt.scatter(x=X_new[y_hc==2, 0], y=X_new[y_hc==2, 1], s=100, c="green", label="Cluster 3" )
# # plt.scatter(x=X_new[y_hc==3, 0], y=X_new[y_hc==3, 1], s=100, c="yellow", label="Cluster 4" )
# # plt.scatter(x=X_new[y_hc==4, 0], y=X_new[y_hc==4, 1], s=100, c="orange", label="Cluster 5" )
# plt.title("Clusters of Countries")
# plt.xlabel("Principal Component 1")
# plt.ylabel("Principal Component 2")
# plt.legend()
# plt.show()
# <b> Classes seem well separated from each other </b>

# %% [markdown]
# #### Exploring the clusters

# %%
# df_final[df_final["Cluster_hc"]==0].describe()
# df_final[df_final["Cluster_hc"]==0]
df_final[df_final["Cluster_hc"]==0].shape
df_final.loc[df_final["Cluster_hc"]==0]#["Country"].unique()
# Out:
#                       Country  Days  CumConfirmed  CumConfirmed_per_million  \
# 0                 Afghanistan   215      0.051817                  0.227524
# 3                      Angola   194      0.008868                  0.045615
# 17                      Benin   197      0.003208                  0.044749
# 25               Burkina Faso   212      0.002984                  0.023843
# 27                    Burundi   176      0.000683                  0.009234
# 30                   Cameroon   213      0.027778                  0.178736
# 32   Central African Republic   186      0.006288                  0.222605
# 33                       Chad   191      0.001719                  0.017323
# 37                    Comoros   159      0.000640                  0.126029
# 38        Congo (Brazzaville)   201      0.006678                  0.206871
# 39           Congo (Kinshasa)   211      0.014166                  0.026470
# ...

# %%
# df_final[df_final["Cluster_hc"]==1].describe()
# df_final[df_final["Cluster_hc"]==1]
df_final[df_final["Cluster_hc"]==1].shape
df_final.loc[df_final["Cluster_hc"]==1]#["Country"].unique()
# Out:
#                     Country  Days  CumConfirmed  CumConfirmed_per_million  \
# 2                   Algeria   225      0.069425                  0.270739
# 5                 Argentina   215      1.109581                  4.207535
# 6                   Armenia   215      0.075956                  4.393146
# 9                Azerbaijan   219      0.055388                  0.935761
# 11                  Bahrain   233      0.099274                 10.000000
# 13                 Barbados   207      0.000276                  0.165511
# 14                  Belarus   201      0.100991                  1.831349
# 20   Bosnia and Herzegovina   217      0.041012                  2.142202
# 22                   Brazil   197      5.824335                  4.696114
# 23                   Brunei   219      0.000188                  0.073980
# 34                    Chile   224      0.625595                  5.608875
# 35                    China   288      0.117735                  0.013375
# ...

# %%
# df_final[df_final["Cluster_hc"]==2].describe()
# df_final[df_final["Cluster_hc"]==2]
df_final[df_final["Cluster_hc"]==2].shape
df_final.loc[df_final["Cluster_hc"]==2]#["Country"].unique()
# Out:
#                               Country  Days  CumConfirmed  \
# 1                             Albania   219      0.020670
# 4                 Antigua and Barbuda   196      0.000143
# 10                            Bahamas   202      0.006723
# 12                         Bangladesh   210      0.492018
# 16                             Belize   188      0.003391
# 18                             Bhutan   157      0.000407
# 19                            Bolivia   213      0.179702
# 21                           Botswana   187      0.004552
# 26                              Burma   192      0.025954
# 28                         Cabo Verde   185      0.009548
# 29                           Cambodia   208      0.000364
# 36                           Colombia   213      1.180775
# 47                           Djibouti   204      0.007046
# 48                           Dominica   198      0.000039
# 49                 Dominican Republic   212      0.153506
# ...

# %%
# df_final[df_final["Cluster_hc"]==3].describe()
# df_final[df_final["Cluster_hc"]==3]
df_final[df_final["Cluster_hc"]==3].shape
df_final.loc[df_final["Cluster_hc"]==3]#["Country"].unique()
# Out:
#                   Country  Days  CumConfirmed  CumConfirmed_per_million  \
# 7               Australia   256      0.035418                  0.237445
# 8                 Austria   227      0.074274                  1.412971
# 15                Belgium   223      0.210233                  3.108693
# 24               Bulgaria   216      0.034454                  0.849338
# 31                 Canada   234      0.248852                  1.129541
# 42                Croatia   224      0.027198                  1.135056
# 45                Czechia   221      0.151735                  2.428072
# 46                Denmark   222      0.042645                  1.261418
# 55                Estonia   221      0.005029                  0.649453
# 59                Finland   221      0.015543                  0.480275
# 60                 France   250      1.062946                  2.790659
# 64                Germany   245      0.388738                  0.794653
# ...

# %%
# df_final.to_csv("C:/Users/user/Downloads/COVID-19 Related Info/df_final_161020_check.csv")

## cluster_hc = 0 (48 countries)
## array(['Afghanistan', 'Angola', 'Benin', 'Burkina Faso', 'Burundi',
##       'Cameroon', 'Central African Republic', 'Chad', 'Comoros',
##       'Congo (Brazzaville)', 'Congo (Kinshasa)', "Cote d'Ivoire",
##      'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gambia',
##      'Ghana', 'Guinea', 'Guinea-Bissau', 'Haiti', 'Kenya', 'Lesotho',
##      'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania',
##      'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Papua New Guinea',
##      'Rwanda', 'Senegal', 'Sierra Leone', 'Solomon Islands', 'Somalia',
##      'South Sudan', 'Sudan', 'Syria', 'Tanzania', 'Timor-Leste', 'Togo',
##      'Uganda', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

## cluster_hc = 1 (42 countries)
## array(['Algeria', 'Argentina', 'Armenia', 'Azerbaijan', 'Bahrain',
##        'Barbados', 'Belarus', 'Bosnia and Herzegovina', 'Brazil',
##        'Brunei', 'Chile', 'China', 'Costa Rica', 'Cuba', 'Cyprus',
##        'Egypt', 'Georgia', 'Greece', 'India', 'Iran', 'Kazakhstan',
##        'Kuwait', 'Malaysia', 'Maldives', 'Mauritius', 'Mexico', 'Moldova',
##        'Montenegro', 'North Macedonia', 'Oman', 'Panama', 'Qatar',
##        'Romania', 'Russia', 'Saudi Arabia', 'Serbia', 'Thailand',
##        'Trinidad and Tobago', 'Turkey', 'US', 'Ukraine', 'Uruguay'],
##       dtype=object)

## Cluster_hc = 2 (52 countries)
## array(['Albania', 'Antigua and Barbuda', 'Bahamas', 'Bangladesh',
##        'Belize', 'Bhutan', 'Bolivia', 'Botswana', 'Burma', 'Cabo Verde',
##        'Cambodia', 'Colombia', 'Djibouti', 'Dominica',
##        'Dominican Republic', 'Ecuador', 'El Salvador', 'Fiji', 'Gabon',
##        'Grenada', 'Guatemala', 'Guyana', 'Honduras', 'Indonesia', 'Iraq',
##        'Jamaica', 'Jordan', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Libya',
##        'Mongolia', 'Morocco', 'Nepal', 'Nicaragua', 'Pakistan',
##        'Paraguay', 'Peru', 'Philippines', 'Saint Kitts and Nevis',
##        'Saint Lucia', 'Saint Vincent and the Grenadines',
##        'Sao Tome and Principe', 'Seychelles', 'South Africa', 'Sri Lanka',
##        'Suriname', 'Tajikistan', 'Tunisia', 'Uzbekistan', 'Venezuela',
##        'Vietnam'], dtype=object)

## cluster_hc =  3 (37 countries)

## array(['Australia', 'Austria', 'Belgium', 'Bulgaria', 'Canada', 'Croatia',
##        'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany',
##        'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy', 'Japan',
##        'Korea, South', 'Latvia', 'Liechtenstein', 'Lithuania',
##        'Luxembourg', 'Malta', 'Netherlands', 'New Zealand', 'Norway',
##        'Poland', 'Portugal', 'Singapore', 'Slovakia', 'Slovenia', 'Spain',
##        'Sweden', 'Switzerland', 'United Arab Emirates', 'United Kingdom'],
##       dtype=object)

# Total 179 countries: left 'Solomon Islands' from cluster 0: Because it was added to COVID-19 data on 16/10/20
# And SOM clusters were snapshot before it. So including it would change the SOM clusters. But the input file to SOM analysis,
# was taken df_final_renamed1 created on 15/10/20 only. Not changed after that.

# %%
## Creating copy of df_final to rename the clusters in line with SOM clusters ahead, It is done after comparing the results 
## (cluster numbers) for the countries from both algorithms
## i.e. comparing cluster_hc column values in 'df_final_161020-ABCD.csv' (created in this cell) with cluster column values in 
## 'data.csv'  (written on disc on getting cluster numbers for countries based on hierarchical clustering on SOM nodes later)


df_final_cluster_hc_renamed = df_final.copy()
df_final_cluster_hc_renamed['Cluster_hc'] = df_final_cluster_hc_renamed['Cluster_hc'].replace({3:'D', 2:'B', 1:'C', 0:'A'}) 

## 3 was Australia group named D here because it is cluster 4 in SOM 
## 0 Afghanistan, Zimbabwe group named A here because it is cluster 1 in SOM
## 1 Algeria, India, US group named C here because it is cluster 3 in SOM 
## 2 Albania, Vietnam group named B here because it is cluster 2 in SOM

## Writing Renamed cluster file to disc
# df_final_cluster_hc_renamed.to_csv("C:/Users/user/Downloads/COVID-19 Related Info/df_final_161020-ABCD.csv")

# %%
df_final_cluster_hc_renamed.dtypes
# df_final.iloc[:, 1:34] = df_final.iloc[:, 1:34].astype(float)
df_final_cluster_hc_renamed.iloc[:, 2:(len(df_final_cluster_hc_renamed.columns)-4)] = df_final_cluster_hc_renamed.iloc[:, 2:(len(df_final_cluster_hc_renamed.columns)-4)].astype(float)

# %%
df_final_cluster_hc_renamed.dtypes
# Out:
# Country                               object
# Days                                   int64
# CumConfirmed                         float64
# CumConfirmed_per_million             float64
# CumDeaths                            float64
# CumRecovered                         float64
# smoothed_cumulative_testing_count    float64
# SmoothedCumTesting_per_thousand      float64
# Population                           float64
# Pop_Density                          float64
# Land_Area_Kmsq                       float64
# HealthCapacityScore                  float64
# RecoveryRate                         float64
# FatalityRate                         float64
# Active                               float64
# P2P                                  float64
# P2P_1                                float64
# P2P_2                                float64
# Vul                                  float64
# Vul_HI                               float64
# Vul_1                                float64
# ...

# %% [markdown]
# #### Summarizing each cluster
# <b> Summarizing each cluster by taking mean of each variable for all countries under that cluster</b>

# %%
df_final1 = df_final_cluster_hc_renamed.groupby("Cluster_hc").mean()
df_final1
# Out:
#                   Days  CumConfirmed  CumConfirmed_per_million  CumDeaths  \
# Cluster_hc
# A           190.708333      0.014426                  0.165008   0.010825
# B           200.423077      0.135483                  1.022166   0.139126
# C           220.833333      0.799147                  2.449860   0.754849
# D           224.108108      0.169885                  1.568788   0.261006
#
#             CumRecovered  smoothed_cumulative_testing_count  \
# Cluster_hc
# A               0.013675                           0.008984
# B               0.134555                           0.050783
# C               0.699218                           0.627559
# D               0.080470                           0.307109
#
#             SmoothedCumTesting_per_thousand  Population  Pop_Density  \
# Cluster_hc
# A                                  0.028592    0.170368     0.038494
# B                                  0.100840    0.191794     0.058017
# ...

# %%
# Renaming the columns for detailed Description
df_final1.rename(columns={
                'Active': 'Active Cases',
                'P2P': 'Risk of Transmission from P2P',
    
                'P2P_1': 'Risk due to lack of basic sanitation & water services',
                'P2P_2': 'Risk associated to Population Distribution', 
                                
                'Vul': 'Vulnerability Index',
    
                'Vul_HI': 'Vulnerability Hazard-independent Risk Index',
                'Vul_1':  'INFORM Socio-Economic Vulnerabiliy Risk Index',
                'Vul_11': 'Vulnerability related to Development & Deprivation', 
                'Vul_12': 'Vulnerability due to Economic & Gender Inequality',
                'Vul_13': 'Vulnerability associated to Economic Dependency Index',
                
                'Vul_2':  'INFORM Vulnerable Groups Risk Index',
                'Vul_21': 'Vulnearbility associated with Uprooted people',
                'Vul_22': 'Vulnerability due to other Health Condns',
                'Vul_23': 'Vulnerability due to lack of Food Security',
                'Vul_24': 'Vulnerability due to Gender Based Violence',   
    
                'Vul_3/Vul_HD':'Covid-19 Overall Vulnerability Index',
                'Vul_31': 'Covid-19-Vul related to International and Internal Movements',
                'Vul_32': 'Covid-19-Vul due to lack of access to authentic information and trust on politicians',
                'Vul_33': 'Covid-19-Vul due to proportion of 1plus underlying condns plus 0 conditions 65plus yrs pop',                 

                'LOCC': "Lack of Coping Capacity Index",
                
                'LOCC_HI':'Lack of Coping Capacity (Hazard-independent) Index',
    
                'LOCC_1': 'INFORM Risk Index related to Institutional Strength',
                'LOCC_11': 'Risk based on Corruption Perception Index',
                'LOCC_12': 'Risk based on Govt Effectiveness',
                
                'LOCC_2':'INFORM Risk Index based on limited operational Infrastructure',
#                 'LOCC_21': 'Risk based on Health System capacity',
                'LOCC_22': 'Risk associated to Immunization coverage',
                'LOCC_23': 'Risk based on per capita public and pvt expenditure on healthcare',
                'LOCC_24': 'Risk based on Maternal Mortality ratio',            
                
                'LOCC_3/LOCC_HD': 'Covid-19 Overall Lack of coping capacity Index',
                'LOCC_31': 'Covid-19 Risk based on International Health Reguation core capacity scores',
                'LOCC_32': 'Covid-19 Risk based on Operational readiness index',    
    
                'CumConfirmed': 'Cumulative Confirmed Count', 'CumDeaths': 'Cumulative Death Count', 
                'CumRecovered': 'Cumulative Recovered Count',
                'smoothed_cumulative_testing_count': 'Smoothed Cumulative Testing Count', 
                'CumConfirmed_per_million': 'Cumulative Confirmed per million',
                'SmoothedCumTesting_per_thousand': 'Smoothed Cumulative Testing per thousand',
                'SmoothedCumTesting_per_CumConfirmed': 'Cumulative Testing per Cumulatve Confirmed Ratio', 
                'Pop_Density': 'Population Density',
                'Land_Area_Kmsq': 'Land Area (Kmsq)', 
                'HealthCapacityScore': 'Health Capacity Score', 
                'RecoveryRate':'Recovery Rate', 
                'FatalityRate':'Fatality Rate',
                }, inplace = True)

# %%
df_final1.head()
# Out:
#                   Days  Cumulative Confirmed Count  \
# Cluster_hc
# A           190.708333                    0.014426
# B           200.423077                    0.135483
# C           220.833333                    0.799147
# D           224.108108                    0.169885
#
#             Cumulative Confirmed per million  Cumulative Death Count  \
# Cluster_hc
# A                                   0.165008                0.010825
# B                                   1.022166                0.139126
# C                                   2.449860                0.754849
# D                                   1.568788                0.261006
#
#             Cumulative Recovered Count  Smoothed Cumulative Testing Count  \
# Cluster_hc
# A                             0.013675                           0.008984
# B                             0.134555                           0.050783
# C                             0.699218                           0.627559
# ...

# %%
# df_final1.columns

# %% [markdown]
# #### Creating heatmap for the clusters
# <b> Heatmap will define the clusters in terms of average values of different variables in them (i.e. constituting countries). </b>

# %%
# 1. Heatmap for all variable: COVID19 variables, Population, Health capacity score, and Risk Indexes

# Filtering out few columns which do not provide clearer picture of difference between various clusters
cols = [#'Cumulative Confirmed Count', 
       'Cumulative Confirmed per million',
       #'Cumulative Death Count', 'Cumulative Recovered Count',
       #'Smoothed Cumulative Testing Count',
       'Smoothed Cumulative Testing per thousand', 
       'Recovery Rate', 'Fatality Rate', 'Active Cases',
       'Population','Population Density', #'Land Area (Kmsq)', 
       'Health Capacity Score',
       
       'Risk of Transmission from P2P',
    
#        'Risk due to lack of basic sanitation & water services',
#        'Risk associated to Population Distribution', 

#        'Vulnerability Index',
    
       'Covid-19 Overall Vulnerability Index',
       'Covid-19-Vul related to International and Internal Movements',
       'Covid-19-Vul due to lack of access to authentic information and trust on politicians',
       'Covid-19-Vul due to proportion of 1plus underlying condns plus 0 conditions 65plus yrs pop',
       
       'Vulnerability Hazard-independent Risk Index',
       'INFORM Socio-Economic Vulnerabiliy Risk Index',
       'Vulnerability related to Development & Deprivation',
       'Vulnerability due to Economic & Gender Inequality',
       'Vulnerability associated to Economic Dependency Index',
       'INFORM Vulnerable Groups Risk Index',
       'Vulnearbility associated with Uprooted people',
       'Vulnerability due to other Health Condns',
       'Vulnerability due to lack of Food Security',
#        'Vulnerability due to Gender Based Violence', 
      
#        'Lack of Coping Capacity Index',
       
       'Covid-19 Overall Lack of coping capacity Index',
       'Covid-19 Risk based on International Health Reguation core capacity scores',
       'Covid-19 Risk based on Operational readiness index',
       
       'Lack of Coping Capacity (Hazard-independent) Index',
       'INFORM Risk Index related to Institutional Strength',
#        'Risk based on Corruption Perception Index',
       'Risk based on Govt Effectiveness',
       'INFORM Risk Index based on limited operational Infrastructure',
#        'Risk based on Health System capacity',
#        'Risk associated to Immunization coverage',
       'Risk based on per capita public and pvt expenditure on healthcare',
#        'Risk based on Maternal Mortality ratio', 
       'INFORM COVID-19 RISK']

# df_final1.loc[:, cols]

# Heatmap
np.random.seed(0)
import seaborn as sns
import matplotlib.pyplot as plt
df_final1_transposed = df_final1.transpose()
plt.figure(figsize=(25,40)) 
# heatmap2 = sns.heatmap(df_final1_transposed.iloc[0:(len(df_final1.transpose())), :],xticklabels=1, annot=True, yticklabels=1, 
#                      annot_kws={"size": 20, "weight":"bold"}, 
#                      cmap="OrRd")
heatmap2 = sns.heatmap(df_final1_transposed.loc[cols, :],xticklabels=1, annot=True, yticklabels=1, 
                     annot_kws={"size": 32, "weight":"bold"}, 
                     cmap="OrRd") #cmap="YlGnBu"
_,ylabels = plt.yticks()
heatmap2.set_yticklabels(ylabels, size=32, fontweight = "bold")
_,xlabels = plt.xticks()
heatmap2.set_xticklabels(xlabels, size=28, fontweight = "bold")
heatmap2.set_xlabel("Cluster",fontsize=30, fontweight = "bold")
# heatmap2.figure.axes[-1].set_ylabel('Value', size=30, yticklabels=20)
cbar = heatmap2.collections[0].colorbar
cbar.ax.tick_params(labelsize=32, width=3, length =4)
cbar.set_label(label='Scaled Value',weight='bold', size = 32)

# heatmap2.invert_yaxis()
heatmap2

# %%
# 2.Creating heatmap for only COVID19, Population and Health Capacity score variables 

# Selecting Required Columns
cols_covid19 = [#'Cumulative Confirmed Count', 
       'Cumulative Confirmed per million',
       #'Cumulative Death Count', 'Cumulative Recovered Count',
       #'Smoothed Cumulative Testing Count',
       'Smoothed Cumulative Testing per thousand', 
       'Recovery Rate', 'Fatality Rate', 'Active Cases',
       'Population','Population Density', #'Land Area (Kmsq)', 
       'Health Capacity Score']
df_final2 = df_final1.loc[:, cols_covid19]


# Heatmap
np.random.seed(0)
import seaborn as sns
import matplotlib.pyplot as plt
df_final2_transposed = df_final2.transpose()
plt.figure(figsize=(17,5)) 
# heatmap21 = sns.heatmap(df_final1_transposed.iloc[0:(len(df_final1.transpose())), :],xticklabels=1, annot=True, yticklabels=1, 
#                      annot_kws={"size": 20, "weight":"bold"}, 
#                      cmap="OrRd")
heatmap21 = sns.heatmap(df_final2_transposed.loc[cols_covid19, :],xticklabels=1, annot=True, yticklabels=1, 
                     annot_kws={"size": 11, "weight":"bold"}, 
                     cmap="YlGnBu") #cmap="OrRd", , Greens
_,ylabels = plt.yticks()
heatmap21.set_yticklabels(ylabels, size=11.5, fontweight = "bold")
_,xlabels = plt.xticks()
heatmap21.set_xticklabels(xlabels, size=10.5, fontweight = "bold")
heatmap21.set_xlabel("Cluster",fontsize=11.5, fontweight = "bold")
heatmap21.set_title('Heatmap for the Covid related variables along with the variables for \n Population and Health Capacity Score for the the four clusters of the countries \n',
                  size = 18)
# heatmap2.figure.axes[-1].set_ylabel('Value', size=30, yticklabels=20)
cbar = heatmap21.collections[0].colorbar
cbar.ax.tick_params(labelsize=8, width=3, length =4)
cbar.set_label(label='Scaled Value',weight='bold', size = 10)

# heatmap2.invert_yaxis()
# heatmap21.figure.savefig('heatmap21.png', bbox_inches='tight')
heatmap21

# %%
# 3.Creating heatmap for only Risk Indexes

# Selecting Required Columns
cols_risk = ['Risk of Transmission from P2P',
    
#        'Risk due to lack of basic sanitation & water services',
#        'Risk associated to Population Distribution', 

#        'Vulnerability Index',
    
       'Covid-19 Overall Vulnerability Index',
       'Covid-19-Vul related to International and Internal Movements',
       'Covid-19-Vul due to lack of access to authentic information and trust on politicians',
       'Covid-19-Vul due to proportion of 1plus underlying condns plus 0 conditions 65plus yrs pop',
       
       'Vulnerability Hazard-independent Risk Index',
       'INFORM Socio-Economic Vulnerabiliy Risk Index',
       'Vulnerability related to Development & Deprivation',
       'Vulnerability due to Economic & Gender Inequality',
       'Vulnerability associated to Economic Dependency Index',
       'INFORM Vulnerable Groups Risk Index',
       'Vulnearbility associated with Uprooted people',
       'Vulnerability due to other Health Condns',
       'Vulnerability due to lack of Food Security',
#        'Vulnerability due to Gender Based Violence', 
      
#        'Lack of Coping Capacity Index',
       
       'Covid-19 Overall Lack of coping capacity Index',
       'Covid-19 Risk based on International Health Reguation core capacity scores',
       'Covid-19 Risk based on Operational readiness index',
       
       'Lack of Coping Capacity (Hazard-independent) Index',
       'INFORM Risk Index related to Institutional Strength',
#        'Risk based on Corruption Perception Index',
       'Risk based on Govt Effectiveness',
       'INFORM Risk Index based on limited operational Infrastructure',
#        'Risk associated to Immunization coverage',
       'Risk based on per capita public and pvt expenditure on healthcare',
#        'Risk based on Maternal Mortality ratio', 
       'INFORM COVID-19 RISK']

df_final3 = df_final1.loc[:, cols_risk]


# Heatmap
np.random.seed(0)
import seaborn as sns
import matplotlib.pyplot as plt
df_final3_transposed = df_final3.transpose()
plt.figure(figsize=(20,30)) 
# heatmap22 = sns.heatmap(df_final1_transposed.iloc[0:(len(df_final1.transpose())), :],xticklabels=1, annot=True, yticklabels=1, 
#                      annot_kws={"size": 20, "weight":"bold"}, 
#                      cmap="OrRd")
heatmap22 = sns.heatmap(df_final3_transposed.loc[cols_risk, :],xticklabels=1, annot=True, yticklabels=1, 
                     annot_kws={"size": 27, "weight":"bold"}, 
                     cmap="OrRd") #cmap="YlGnBu"
_,ylabels = plt.yticks()
heatmap22.set_yticklabels(ylabels, size=27, fontweight = "bold")
_,xlabels = plt.xticks()
heatmap22.set_xticklabels(xlabels, size=25, fontweight = "bold")
heatmap22.set_xlabel("Cluster",fontsize=30, fontweight = "bold")
heatmap22.set_title("Heatmap for INFORM Risk Indexes for the \n four clusters of the countries", size = 35, fontweight = "bold")
# heatmap2.figure.axes[-1].set_ylabel('Value', size=30, yticklabels=20)
cbar = heatmap2.collections[0].colorbar
cbar.ax.tick_params(labelsize=28, width=3, length =4)
cbar.set_label(label='Scaled Value',weight='bold', size = 28)

# heatmap2.invert_yaxis()
# heatmap22.figure.savefig('heatmap22.png', bbox_inches='tight')
heatmap22

# %% [markdown]
# ### Hierarchical Clustering on Self Organizing Maps (SOM) Nodes

# %% [markdown]
# <b> Preparing R environment in Python Jupyter Notebook </b>

# %%
# conda install r-essentials
# conda install rpy2
# import rpy2
# print(rpy2.__version__)

# %%
import os
os.environ['R_HOME'] = "C:/Users/user/anaconda3/Lib/R"
# os.environ['R_USER'] = "C:/Users/user/anaconda3/pkgs/rpy2-2.9.4-py37r36h39e3cac_0/Lib/site-packages/rpy2"
os.environ['R_USER'] = "C:/Users/user/anaconda3/pkgs/rpy2-3.3.2-py37r36h9dff50a_0/Lib/site-packages/rpy2"

# %%
import rpy2
import rpy2.rinterface as rinterface
import rpy2.robjects as robjects

# %%
rinterface.initr()

# %%
# conda install tzlocal
# %load_ext rpy2.ipython
# Out:
# C:\Users\user\anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %% [markdown]
# <b> Installing required packages and importing libraries </b>

# %%
# %%R
#
# # Load the kohonen package
# # install.packages(c("kohonen", "viridis"),repos='http://cran.us.r-project.org')
# library(kohonen)
# library(viridis)
# library(dplyr)

# %% [markdown]
# #### Creating Color palattes to be used for Self Organizing Maps

# %%
# %%R
# # coolBlueHotRed <- function(n, alpha = 1) {
# #  rainbow(n, end=4/6, alpha=alpha)[n:1]}
#
# # Define color Palettes
# vircols <- function(n, alpha = 1) {
#   viridis(n,alpha=alpha ,begin=0.2,end=0.97)[n:1]}
#
# pretty_palette <- c("#1f77b4","#ff7f0e","#2ca02c",
#                     "#d62728","#9467bd","#8c564b",
#                     "#e377c2")

# %% [markdown]
# #### Reading Data
# <b> Reading the df_final_renamed (merged file for COVID-19 data and INFORM COVID-19 risk data, with variables renamed for description) created above.

# %%
# %%R
# # Reading data set (rows are samples, columns are variables
# data <- read.csv("C:/Users/user/Downloads/COVID-19 Related Info/df_final_renamed1.csv")
# # df_final <- read.csv("C:/Users/user/Downloads/COVID-19 Related Info/df_final.csv")

# %%
# %%R
# head(data)

# %%
# %%R
# colnames(data)

# %%
# %%R
# #sum(is.nan(data))
# sapply(data, class)

# %% [markdown]
# #### Preparing Training Data for SOM

# %%
# %%R
# # Filtering/Selecting columns for clustering
# data_f <- data %>% select(4:(ncol(data)-4))

# %%
# %%R
# head(data_f)

# %%
# %%R
# # Change the data frame with training data to a
# # matrix. Also center and scale all variables (if
# # not already) to give them equal importance
# # during the SOM training process.
#
# data_f_matrix <- as.matrix(data_f)

# %% [markdown]
# #### Training SOM

# %%
# %%R
# # Select the size and type of the map
# set.seed(33)
# som_grid <- somgrid(xdim = 12, ydim=12,
#                     topo="hexagonal")
#
# # Train the SOM, using options for the number of
# # iterations,the learning rates
#
# som_model <- som(data_f_matrix,
#                  grid=som_grid,
#                  rlen=6000,
# #                  alpha=c(0.05,0.01),
#                  keep.data = TRUE)

# %%
# %%R
# # To know the data position in maps, we look it
# # in unit.classif. Each value represents the node
# # number to which the country belongs
#
# som_model$unit.classif

# %%
# %%R
# # We can see the classification of each node by
# # codes plot and we can see the values of each
# # node using the mapping plot
#
# par("mar")
# # par(mar = c(1,1,1,1))
# # par(oma = c(0, 0, 1, 0))
# plot(som_model, type = "mapping", pchs = 19,
#      shape = "round")
# # plot(som_model, type="codes")
# plot(som_model, type="codes", codeRendering ="segments")
#
# # As the SOM training iterations progress, the
# # distance from each node's weights to the samples
# # represented by that node is reduced. Ideally,
# # this distance should reach a minimum plateau.
# # This plot option shows the progress over time.
# # If the curve is continually decreasing, more
# # iterations are required.
#
# plot(som_model, type="changes")
#
#
# # The Kohonen packages allows us to visualise the
# # count of how many samples are mapped to each
# # node on the map. This metric can be used as a
# # measure of map quality - ideally the sample
# # distribution is relatively uniform. Large values
# # in some map areas suggests that a larger map
# # would be benificial. Empty nodes indicate that
# # your map size is too big for the number of samples.
# # Aim for at least 5-10 samples per node when
# # choosing map size.
#
# # plot(som_model, type="count")
#
# # Often referred to as the "U-Matrix", this
# # visualisation is of the distance between each
# # node and its neighbours. Typically viewed with
# # a grayscale palette, areas of low neighbour
# # distance indicate groups of nodes that are
# # similar. Areas with large distances indicate
# # the nodes are much more dissimilar - and
# # indicate natural boundaries between node
# # clusters. The U-Matrix can be used to identify
# # clusters within the SOM map.
#
# # plot(som_model, type="dist.neighbours")
#
# # SOM heatmap visualisation of the distribution
# # of a single variable across the map (here column 4)
#
# # plot(som_model, type = "property",
# #      property = getCodes(som_model)[,4],
# #      main=colnames(getCodes(som_model))[4],
# #      palette.name=vircols)

# %% [markdown]
# #### Performing Hierarchical clustering on SOM nodes

# %%
# %%R
# # CLUSTERING
#
# # Performing clustering on SOM nodes to isolate
# # groups of samples with similar metrics.
#
# # Clustering SOM map using hierachical clustering.
# # The results of the clustering can be visualised
# # using the SOM plot function.
#
# mydata <- as.data.frame(som_model$codes)
# lapply(mydata, as.numeric)
# dendrogram <- hclust(dist(mydata,
#                           method = "euclidean"),
#                      method ="ward.D2")
#
# par(mfrow= c(2,1))
# plot(dendrogram)

# %%
# %%R
# plot(dendrogram)

# %% [markdown]
# <b> Optimal number of clusters = 4 </b>

# %% [markdown]
# #### Plotting the clusters (for SOM nodes)

# %%
# %%R
# som_cluster <- cutree(dendrogram, 4)
#
# # Mapping clusters back to original samples
# # Get vector with cluster value for each original
# # data sample
# cluster_assignment <- som_cluster[som_model$unit.classif]
#
# # For each of analysis, add the assignment as a
# # column in the original data:
# data$cluster <- cluster_assignment
#
# # Plot these results:
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters",labels = as.integer(data$cluster), col = as.integer(data$cluster) )
# add.cluster.boundaries(som_model, som_cluster)
#
#
# # Exploring clusters
# write.csv(data,"C:/Users/user/Downloads/COVID-19 Related Info/data_161020.csv")
# c1 <- data[data$cluster==1,]
# c2 <- data[data$cluster==2,]
# c3 <- data[data$cluster==3,]
# c4 <- data[data$cluster==4,]

# %% [markdown]
# #### Visualizing Clusters and the distribution of variables in them

# %% [markdown]
# ##### Visualizing clusters and COVID-19 data variables distribution in the clusters

# %%
# %%R
# par(mfrow=c(3,2))
# # par(mar = c(5.1, 4.1, 4.1, 2.1))
# # par(mar = c(1, 1, 0.1, 1))
# # par(oma = c(0, 0, 0.5, 0))
#
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters", cex.main=0.20)
# add.cluster.boundaries(som_model, som_cluster)
#
# # list = c(2, 6, 14, 15, 18, 19, 20, 29, 31)
#
#
# for (i in 1:13) {
#   plot(som_model, type = "property",
#        property = getCodes(som_model)[,i],
#        main=colnames(getCodes(som_model))[i],
#        palette.name=vircols)
#   add.cluster.boundaries(som_model, som_cluster)
#
# }

# %% [markdown]
# ##### Visualizing clusters and distribution of INFORM Risk data variables in the clusters
# ###### Risks due to  Hazard and Exposure Components

# %%
# %%R
# par(mfrow=c(3,2))
# # par(mar = c(5.1, 4.1, 4.1, 2.1))
# # par(mar = c(1, 1, 0.1, 1))
# # par(oma = c(0, 0, 0.5, 0))
#
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters", cex.main=0.20)
# add.cluster.boundaries(som_model, som_cluster)
#
# # list = c(2, 6, 14, 15, 18, 19, 20, 29, 31)
#
#
# for (i in 14:16) {
#   plot(som_model, type = "property",
#        property = getCodes(som_model)[,i],
#        main=colnames(getCodes(som_model))[i],
#        palette.name=vircols)
#   add.cluster.boundaries(som_model, som_cluster)
#
# }

# %% [markdown]
# ###### Risks due to Vulnerability (Hazard Independent) components

# %%
# %%R
# par(mfrow=c(3,2))
# par(xpd=NA)
# # par(mar = c(5.1, 4.1, 4.1, 2.1))
# # par(mar = c(1, 1, 0.1, 1))
# # par(oma = c(0, 0, 0.5, 0))
#
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters", cex.main=0.20)
# add.cluster.boundaries(som_model, som_cluster)
#
# # list = c(2, 6, 14, 15, 18, 19, 20, 29, 31)
#
#
# for (i in 18:27) {
#   plot(som_model, type = "property",
#        property = getCodes(som_model)[,i],
#        main=colnames(getCodes(som_model))[i],
#        palette.name=vircols)
#   add.cluster.boundaries(som_model, som_cluster)
#
# }

# %% [markdown]
# ###### Risks due to COVID-19 (Hazard Dependent) Vulnerability  components

# %%
# %%R
# par(mfrow=c(3,2))
# par(xpd=NA)
# # par(mar = c(5.1, 4.1, 4.1, 2.1))
# # par(mar = c(1, 1, 0.1, 1))
# # par(oma = c(0, 0, 0.5, 0))
#
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters", cex.main=0.20)
# add.cluster.boundaries(som_model, som_cluster)
#
# # list = c(2, 6, 14, 15, 18, 19, 20, 29, 31)
#
#
# for (i in 28:31) {
#   plot(som_model, type = "property",
#        property = getCodes(som_model)[,i],
#        main=colnames(getCodes(som_model))[i],
#        palette.name=vircols)
#   add.cluster.boundaries(som_model, som_cluster)
#
# }

# %% [markdown]
# ###### Risks associated to Lack of Coping Capacity (Hazard Independent) components

# %%
# %%R
# par(mfrow=c(3,2))
# par(xpd=NA)
# # par(mar = c(5.1, 4.1, 4.1, 2.1))
# # par(mar = c(1, 1, 0.1, 1))
# # par(oma = c(0, 0, 0.5, 0))
#
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters", cex.main=0.20)
# add.cluster.boundaries(som_model, som_cluster)
#
# # list = c(2, 6, 14, 15, 18, 19, 20, 29, 31)
#
#
# for (i in 33:40) {
#   plot(som_model, type = "property",
#        property = getCodes(som_model)[,i],
#        main=colnames(getCodes(som_model))[i],
#        palette.name=vircols)
#   add.cluster.boundaries(som_model, som_cluster)
#
# }

# %% [markdown]
# ###### Risks associated to COVID-19 (Hazard Dependent) Lack of Coping Capacity components

# %%
# %%R
# par(mfrow=c(3,2))
# par(xpd=NA)
# # par(mar = c(5.1, 4.1, 4.1, 2.1))
# # par(mar = c(1, 1, 0.1, 1))
# # par(oma = c(0, 0, 0.5, 0))
#
# plot(som_model, type="mapping",
#      bgcol = pretty_palette[som_cluster],
#      main = "Clusters", cex.main=0.20)
# add.cluster.boundaries(som_model, som_cluster)
#
# # list = c(2, 6, 14, 15, 18, 19, 20, 29, 31)
#
#
# for (i in 41:43) {
#   plot(som_model, type = "property",
#        property = getCodes(som_model)[,i],
#        main=colnames(getCodes(som_model))[i],
#        palette.name=vircols)
#   add.cluster.boundaries(som_model, som_cluster)
#
# }
