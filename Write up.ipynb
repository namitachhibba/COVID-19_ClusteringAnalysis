# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Data-Preparation--(Phase-1)-" data-toc-modified-id="Data-Preparation--(Phase-1)--2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Preparation <i> (Phase 1) </i></a></span><ul class="toc-item"><li><span><a href="#-Step-1:-Loading-Data-" data-toc-modified-id="-Step-1:-Loading-Data--2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><b> Step 1: Loading Data </b></a></span><ul class="toc-item"><li><span><a href="#-Links-to-the-Sources---" data-toc-modified-id="-Links-to-the-Sources----2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span><b> Links to the Sources </b> <br> <br></a></span></li><li><span><a href="#-Reading-the-raw-data-from-the-source--" data-toc-modified-id="-Reading-the-raw-data-from-the-source---2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span><b> Reading the raw data from the source </b> <br><br></a></span></li></ul></li><li><span><a href="#Step-2:-Data-Cleaning-and-Manipulation" data-toc-modified-id="Step-2:-Data-Cleaning-and-Manipulation-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Step 2: Data Cleaning and Manipulation</a></span><ul class="toc-item"><li><span><a href="#-“Confirmed-Cases”-,-“Deaths”,-“Recovered-Cases”--data-" data-toc-modified-id="-“Confirmed-Cases”-,-“Deaths”,-“Recovered-Cases”--data--2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span><b> “Confirmed Cases” , “Deaths”, “Recovered Cases” </b> data <br><br></a></span></li><li><span><a href="#-“Testing-Counts”-" data-toc-modified-id="-“Testing-Counts”--2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span><b> “Testing Counts” </b></a></span></li><li><span><a href="#-“Population”-,-“Population-Density”--data-" data-toc-modified-id="-“Population”-,-“Population-Density”--data--2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span><b> “Population” , “Population Density” </b> data <br><br></a></span></li><li><span><a href="#-“Health-Capacity-Score”--data-" data-toc-modified-id="-“Health-Capacity-Score”--data--2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span><b> “Health Capacity Score” </b> data <br><br></a></span></li></ul></li><li><span><a href="#-Step-3:-Data-Fusion-" data-toc-modified-id="-Step-3:-Data-Fusion--2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span><b> Step 3: Data Fusion </b></a></span></li><li><span><a href="#Data-Transformation" data-toc-modified-id="Data-Transformation-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Data Transformation</a></span><ul class="toc-item"><li><span><a href="#Deriving-Daily-Confirmed,-Deaths,-Recovered,-Testing-counts-from-Cumulative-Confirmed,-Deaths,-Recovered,-Testing-counts-using-existing-columns-in-MergedData-dataframe" data-toc-modified-id="Deriving-Daily-Confirmed,-Deaths,-Recovered,-Testing-counts-from-Cumulative-Confirmed,-Deaths,-Recovered,-Testing-counts-using-existing-columns-in-MergedData-dataframe-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Deriving Daily Confirmed, Deaths, Recovered, Testing counts from Cumulative Confirmed, Deaths, Recovered, Testing counts using existing columns in MergedData dataframe</a></span></li><li><span><a href="#Deriving-Active-Cases,-Recovery-Rate-and-Testing-Ratios-(Cumulative-Testing-per-Population,-Daily-Testing-per-1000,-Daily-Testing-Count-per-Daily-Confirmed-Count)-from-the-available-columns-in-the-MergedData-using-following-formula" data-toc-modified-id="Deriving-Active-Cases,-Recovery-Rate-and-Testing-Ratios-(Cumulative-Testing-per-Population,-Daily-Testing-per-1000,-Daily-Testing-Count-per-Daily-Confirmed-Count)-from-the-available-columns-in-the-MergedData-using-following-formula-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Deriving Active Cases, Recovery Rate and Testing Ratios (Cumulative Testing per Population, Daily Testing per 1000, Daily Testing Count per Daily Confirmed Count) from the available columns in the MergedData using following formula</a></span></li><li><span><a href="#Extracting-present-date-data-for-all-countries-from-the-above-dataframe-consisting-of-data-for-multiple-days-for-the-countries" data-toc-modified-id="Extracting-present-date-data-for-all-countries-from-the-above-dataframe-consisting-of-data-for-multiple-days-for-the-countries-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Extracting present date data for all countries from the above dataframe consisting of data for multiple days for the countries</a></span></li></ul></li><li><span><a href="#Final-Datasets:" data-toc-modified-id="Final-Datasets:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Final Datasets:</a></span></li></ul></li></ul></div>

# %% [markdown]
# <b> COVID-19 Study: A Data Analytics Project </b>
#
# ### Introduction
#
# Understanding of COVID-19 data educates the people, organizations and the governments of the countries about the development  and progression of the disease in the world and in their country. It is very important to be aware about how steadily and severely the virus is advancing, to cope with it by updating the stringency of the regulatory laws on businesses, people’s movements and travel.
#
# This project aims to understand the COVID-19 severity worldwide by analyzing the country wise data for COVID-19 in terms of cumulative confirmed cases, deaths, recovered cases and testing count. The information regarding population and population density for the countries is also included to understand their correlation if any with the spread of disease and its impact.
#
# As in any data analytics project, this project involves three phases.
# - Phase 1: Data Preparation
# - Phase 2: Data Exploration
# - Phase 3: Data Modelling
#
# So let’s begin our step by step journey to uncover COVID-19 situations in individual countries and their comparison with each other.

# %% [markdown]
# ### Data Preparation <i> (Phase 1) </i>
#
# Data preparation is the first step in data analytics projects and can include many discrete tasks such as loading data, data fusion, data cleaning, data augmentation, data transformation and data delivery.
#
# Our project will involve the majority of these tasks viz.
# - <b> Step 1: Loading Data: </b>
#
# <i> Copying and loading data sets from source files </i>
#
#
# - <b> Step 2: Data Cleaning </b>
#
# <i> Detecting and correcting corrupt or inaccurate records from a table, or dataframe and identifying incomplete, incorrect, inaccurate or irrelevant parts of the data and then replacing, modifying, or deleting the dirty or coarse data. </i>
#
# - <b> Step 3: Data Fusion:  </b>
#
# <i> Integrating multiple data sources to produce more consistent, accurate, and useful information than that provided by any individual data source.</i>
#
# - <b> Step 4: Data Transformation </b>
#
# <i> Converting data from one format or structure into another format or structure. </i>
#
# Taking one step at a time…

# %% [markdown]
# #### <b> Step 1: Loading Data </b>
#
#
# #####  <b> Links to the Sources </b> <br> <br>
#
# 1. COVID-19 data for <b>“Confirmed Cases”, “Deaths”, “Recovered Cases”</b>  is being provided by John Hopkins University CSSE through their public repository in Github [here](https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series) in the following files:
#
#     - Confirmed Cases Data: [time_series_covid19_confirmed_global.csv](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv)
#     - Deaths Data: [time_series_covid19_deaths_global.csv](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv)
#     - Recovered Cases Data: [time_series_covid19_recovered_global.csv](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv) <br><br>
#
# 2. For <b>“Testing Count”</b> data the source is “Our World in Data” and the data is available on Github on this [link](https://github.com/owid/covid-19-data/tree/master/public/data/testing). And the file used is:
#     - Testing Data: [covid-testing-all-observations.csv](https://github.com/owid/covid-19-data/blob/master/public/data/testing/covid-testing-all-observations.csv) <br> <br>
#
# 3. <b>“Population” and “Population density”</b> data is taken from [worldometers website](https://www.worldometers.info/world-population/population-by-country/)
# <br><br>
# 4. <b>"Health Capacity Index"</b> data
#
#    <i>"Health Capacity Score" is an index for health Capacity in clinics, hospitals and community care centres for the country </i><br><br>
#    The indicator score is the weighted sum of the following sub-indicator scores:
#     1. Available human resources for the broader healthcare system (50%)
#     2. Facilities capacity (50%)
#
#    The data is taken from [Global Health Security Index website] (https://www.ghsindex.org/) <br> <br>
#
# #####  <b> Reading the raw data from the source </b> <br><br>
#
# 1. <b>“Confirmed Cases”, “Deaths”, “Recovered Cases”</b>
#
#     The Confirmed Cases, Deaths and Recovered cases are in the same format so follow the same steps of data preparation. So we will discuss the steps for Confirmed Cases data and apply the same to Deaths and Recovered Cases data. Following is the snippet for the “Confirmed Cases” data: <br> <br>
#
#     <div style="text-align: left"><img src="vid1.gif" width="700" /></div>
#
#    We find that our data has a long list of columns consisting of “Country/Region” “Province/State” (corresponding to Country/Region), “Lat”, “Long” and rest of the columns are for each date since 1/22/20. <br> <br>
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig1.PNG" width="700" /></div> <br> <br>
#
# 2. <b> “Testing” </b> count data
#
#     “Testing” data looks as below:
#
#     <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig2.PNG" width="700" /></div> <br> <br>
#
# 3. <b> “Population” and “Population Density” </b>
#
#     The information gathered from worldometers regarding “Population” and “Population Density” (which is “Population”/”Land_Area_Kmsq”) is in the following form:
#
#       <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig3.PNG" width="400" /></div> <br> <br>
#
# 4. <b> "Health Capacity Score"</b>
#
#    The data for health capacity score is in following form:
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig4.PNG" width="200" /></div> <br> <br>

# %% [markdown]
# #### Step 2: Data Cleaning and Manipulation
#
#
# ##### <b> “Confirmed Cases” , “Deaths”, “Recovered Cases” </b> data <br><br>
#
# 1. Checking for the null values in the data <br><br>
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig5.PNG" width="800" /></div>
#
#    Luckily, our data for Confirmed Cases, Deaths, Recovered Cases have zero null values. <br> <br>
#
# 2. Removing the not required columns or rows
#
#    Since our interest is in analyzing the data country wise and not to focus on different provinces of the data, hence we group the data by “Country/Region” and also remove the “Lat” and “Long” columns as we don’t intend to use them in our project. Also since we have some data related to two Cruise  Ships ("Diamond Princess", "MS Zaandam")  within the Countries data, we remove it too. <br> <br>
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig6.png" width="800" /></div> <br> <br>
#
# 3. Adding data for countries from 01/01/20 to 01/21/20. For all other countries except China the data for “Confirmed Cases”,        “Deaths”, “Recovered Cases” is zero from 01/01/20 to 01/21/20.
#    But for China the numbers take from a China CDC publication are as follows: <br> <br>
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig9.PNG" width="300" /></div>
#
#    So after removing unrequired columns and rows, adding the data for China and all other countries from 01/01/20 to                01/21/20 to the data read from Github and finally grouping the data by “Country/Region” looks like this:
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig7.png" width="800" /></div> <br> <br>
#
# 4. Shifting all data to one starting point & converting the Dates format to Days <br><br>
#    Converting the Dates format to Days to bring all countries data to start from one starting point i.e. day “1” which would        be the day on which the confirmed cases for the country reached 10 or more <br>
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid2.gif" width="700" /></div> <br> <br>
#
# 5. Unpivot the days columns to a column with name “Days” and value name “Confirmed Cases”
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig8.png" width="300" /></div> <br> <br>
#
# And here it is!
#
# We follow the same steps for “Deaths” and “Recovered Cases” data, only the difference that when we change the dates to days as in part D above (of Data Cleaning), we keep the day 1 as a day on which the number of “Confirmed Cases” for the country reached 10 or more. Which means we do not define the day 1 in “Deaths” data as the day on which deaths for the country reached 10 or more or in case of “Recovered cases” day 1 is not defined by day on which number of recovered cases reached 10 or more but we keep the day 1 as the day on which “Confirmed Cases”  for the country reached 10 or more again. This way we will have day 1 as a unique element for every country irrespective of whether we are dealing with “Confirmed Cases” , “Deaths” or “Recovered Cases” and even for “Testing Counts” we are going to discuss in the following part.
#
# So after doing the above for “Deaths” and “Recovered Cases” data we will have the following 2 dataframes for “Deaths” and “Recovered Cases” respectively.
#
# > <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig10.png" width="300" /></div> <br> <br>
# > <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig11.png" width="300" /></div>
#
# ##### <b> “Testing Counts” </b>
#
# 1. Removing the not required columns in the Testing data. We only keep the following three columns and remove everything else from the data. <br> <br>
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig12.PNG" width="400" /></div> <br> <br>
#
# 2. Change the name of the “Entity” column to "Country/Region" as in Confirmed Cases, Deaths and Recovered Cases datasets and “Cumulative total" to “Cumulative_Testing_Count" <br> <br>
#
# 3. Get the country name from the value under Entity column like: "Argentina" from "Argentina - tests performed"
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig13.PNG" width="400" /></div> <br> <br>
#
# 4. Changing the "Date" column from object type to type datetime and then changing it to the format present in Confirmed Cases/ Deaths/Recovered Cases datasets for "Dates"
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig14.PNG" width="800" /></div> <br> <br>
#
# 5. Pivoting the Testing data such that the individual dates form the separate columns
#
#    <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid3.gif" width="500" /></div>
#
#    Every country has "Testing" data available from different dates but on pivoting dates start from 01/01/20 or all countries because one of the countries "Mexico" has the "Testing" data available from this date (the earliest date amongst all countries). So as a result on pivoting, the date columns start from this date. And we will have null values for every other country from 01/01/20 till the date on which the country had testing data reported for the first time. For example for "Argentina" the testing data is available from 04/08/20, so we see "NaN" values from 01/01/20 to 04/07/20. Same is true for other countries. <br> <br>
#
# 6. Filling Missing values with appropriate values
#
#     There are two kinds of null values in “Testing” data <br> <br>
#
#     1. The null values before the 1st non-empty value for testing of the country. For example        for Australia the “Testing” data is available from 03/22/20 but since the date columns        start from 01/01/20 so there will be NaN values present from 01/01/20 to 03/21/20 for        Australia.
#
#     <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid4.gif" width="500" /></div> <br> <br>
#
#     2. Besides that even after the “Testing” data gets started to be collected by the country        on a specific date but still after that date there are null values which refer to the        dates for which the testing data was not updated.For example for Australia first              "Testing" data observation is present on 03/22/2020 but after that there are missing          values from 03/23/20 to 03/28/20 and further from 03/30/20 to 04/04/20.
#
#     <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid5.gif" width="500" /></div> <br> <br>
#
#     How to deal with it?
#
#      - First we replace the in between missing values with the previous non-null value. For          example for Australia we will fill the null values from 03/23/20 to 03/28/20 with            value at 03/22/20 and the null values from 03/30/20 to 04/04/20 with value at 03/29/20       <br> <br>
#
#      <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid6.gif" width="500" /></div> <br> <br>
#
#      - After this we will have null values only before the first non-null testing value for          the country. For example for Australia the null values for “Testing” data are now only        present from 01/01/20 to 03/21/20 and so since no testing was done during this time          period for Australia so we can safely replace these null values with zeros.
#
#      <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid7.gif" width="500" /></div> <br> <br>
#
#       Hence, now we have no null values in our testing data! Awesome!<br> <br>
#
# 7. Preparing the testing data to be merged with the "Confirmed Cases"/"Deaths"/"Recovered"      Cases datasets by aligning the "Country/Region" column
#
#     After merging the “Confirmed Cases” data (which is consistent with “Deaths”, and “Recovered Cases” data in terms of number of rows i.e. same names under “Country/Region” column) with the testing data by applying outer join we can check that there are some countries which are only present in “Confirmed Cases” data and few are only present in        “Testing” data. Rather we see that there is 186 countries information in “Confirmed Cases”  data and only 86 countries information in “Testing” data. Moreover there are some countries which are present as different names in “Testing” data in comparison to "Confirmed Cases” data and vice versa. For example:
#
#     - ‘Taiwan’ : ‘Taiwan*’
#     - 'United States': 'US'
#     - ‘Czech Republic’ : ‘Czechia’
#     - ‘South Korea’: ‘Korea, South’
#     - ‘Myanmar’: ‘Burma’
#
#    After making the “Country/Region” name same in both the datasets we merge the “Testing” data with the “Country/Region” column of the “Confirmed Cases” data such that we have all the “Country/Region” values which are there in “Confirmed Cases” (or “Deaths or “Recovered Cases” data)
#
#     So, after this even our “Testing” data has 186 countries under “Country/Region” column <br> <br>
#
# 8. Shifting all data to one starting point & converting the Dates format to Days <br> <br>
#
#      Converting the Dates format to Days to bring all countries data to start from one starting point day "1" which would be the day on which the confirmed cases for the country reached 10 or more as done for “Confirmed Cases”, “Deaths”  and “Recovered Cases” data. <br> <br>
#
# 9. Unpivot the days columns to a column with name “Days” and value name “Testing Count” <br> <br>
#
#     And we get the following output.
#
#     <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig15.png" width="300" /></div>
#
#
# ##### <b> “Population” , “Population Density” </b> data <br><br>
#
# 1. To match country names in population data with the country names in our created MergedData above so that we can join them properly¶
#
#     After merging the “Confirmed Cases” data (which is in alignment with “Deaths”, and “Recovered Cases” data in terms on same values under “Country/Region” column) with the “Population” data, by applying outer join we can check that there are some countries which are only present in “Confirmed Cases” data and some are only present in “Population” data. Rather we see that there is 186 countries information in “Confirmed Cases”  data and 235 countries information in “Population” data. Moreover there are some countries which are present as different names in “Population” data in comparison to “Confirmed Cases” data and vice versa. For example:
#
#     - ‘Myanmar’ - ‘Burma’
#     - ‘Congo’ - ‘Congo (Brazzaville)’
#     - ‘DR Congo’ - ‘Congo (Kinshasa)’
#     - ‘Côte d'Ivoire’ - ‘Cote d'Ivoire’
#     - ‘Czech Republic (Czechia)’ - ‘Czechia’
#     - ‘South Korea’ - ‘Korea, South’
#     - ‘Saint Kitts & Nevis’ - ‘Saint Kitts and Nevis’
#     - ‘St. Vincent & Grenadines’ - ‘Saint Vincent and the Grenadines’
#     - ‘Sao Tome & Principe’ - ‘Sao Tome and Principe’
#     - ‘United States’ - ‘US’
#     - ‘State of Palestine’ - ‘West Bank and Gaza’
#
#     After making the “Country/Region” name same in both the datasets we merge the “Population” data with     the “Country/Region” column of the “Confirmed Cases” data such that we have all the “Country/Region”     values which are there in “Confirmed Cases” (or “Deaths or “Recovered Cases” data)
#
#     So, after this even out “Population” data has 186 values under “Country/Region” column
#
# ##### <b> “Health Capacity Score” </b> data <br><br>
#
# 1. To match country names in health capacity score data with the country names in our created MergedData above so that we can join them properly
#
#    After merging the “Confirmed Cases” data (which is in alignment with “Deaths”, and “Recovered Cases” data in terms on same values under “Country/Region” column) with the “Health Capacity Score” data, by applying outer join we can check that there are some countries which are only present in “Confirmed Cases” data and some are only present in “Health Capaciy Score” data. Rather we see that there is 186 countries information in “Confirmed Cases”  data and 195 countries information in “Health Capacity Score” data. Moreover there are some countries which are present as different names in “Health Capacity Score” data in comparison to “Confirmed Cases” data and vice versa. For example:
#
#  - Congo (Democratic Republic) - Congo (Kinshasa)
#  - Côte d'Ivoire - Cote d'Ivoire
#  - Czech Republic - Czechia
#  - eSwatini (Swaziland) - Eswatini
#  - Kyrgyz Republic - Kyrgyzstan
#  - Myanmar - Burma
#  - South Korea - Korea, South
#  - St Kitts and Nevis- Saint Kitts and Nevis
#  - St Lucia - Saint Lucia
#  - St Vincent and The Grenadines - Saint Vincent and the Grenadines
#  - São Tomé and Príncipe - Sao Tome and Principe
#  - United States - US
#
#    After making the “Country/Region” name same in both the datasets we merge the “Health Capacity Score” data with the “Country/Region” column of the “Confirmed Cases” data such that we have all the “Country/Region” values which are there in “Confirmed Cases” (or “Deaths or “Recovered Cases” data)
#
#    So, after this even our “Health Capacity Score” data has 186 countries under “Country/Region” column

# %% [markdown]
# #### <b> Step 3: Data Fusion </b>
#
# Merging the 6 datasets viz. “Cumulative Confirmed Count”, “Cumlative Death Count”, “Cumulative Recovered Count”, “Cumulative Testing Count”, “Population” data, and "Health Capacity Score" data over the “Country/Region” our resulting dataframe has the following form:
#
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig16.png" width="800" /></div> <br> <br>
#
# Let's name this dataframe as <b> MergedData </b>. <br> <br>

# %% [markdown]
# #### Data Transformation
#
# ##### Deriving Daily Confirmed, Deaths, Recovered, Testing counts from Cumulative Confirmed, Deaths, Recovered, Testing counts using existing columns in MergedData dataframe
#
# Doing differencig we can deduce the daily counts from cumulative counts. For example for "Daily Confirmed Count" we apply differencing on "Cumulative Confirmed Count" as follows:
#
# > <font color = blue> MergedData['Daily Confirmed Count'] = MergedData['Cumulative Confirmed Count'].diff().fillna(MergedData["Cumulative Confirmed Count"]) </font> <br> <br>
#
# And we do the same for "Daily Death Count", "Daily Recovered Count" and "Daily Testing Count"
#
# <br> <br>
#
# #####  Deriving Active Cases, Recovery Rate and Testing Ratios (Cumulative Testing per Population, Daily Testing per 1000, Daily Testing Count per Daily Confirmed Count) from the available columns in the MergedData using following formula
#
# - <font color = blue> "ActiveCases" = "Cumulative Confirmed Count" - "Cumulative Recovered Count" - "Cumulative Death Count" </font> <br>
#
# - <font color = blue> "RecoveryRate" = "Cumulative Recovered Count" / "Cumulative Confirmed Count </font> <br>
#
# - <font color = blue> "CumTesting_per_Population"= "Cumulative Testing Count" / "Population"</font> <br>
#
# - <font color = blue> "DailyTesting_per_1000" = "Daily Testing Count"/ 1000 </font> <br>
#
# - <font color = blue> "DailyTesting_per_DailyConfirmed" = "Daily Testing Count" / "Daily Confirmed Count" </font>
#
# Our dataset looks like as below after adding above columns.
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid8.gif" width="550", height ="900" /></div> <br> <br>
#
# ##### Extracting present date data for all countries from the above dataframe consisting of data for multiple days for the countries
#
# Renaming the column names for convenience first.
#
# - Country/Region : Country <br>
# - Cumulative Confirmed Count : CumConfirmed <br>
# - Cumulative Death Count : CumDeaths <br>
# - Cumulative Recovered Count : CumRecovered <br>
# - Cumulative Testing Count : CumTesting <br>
# - Daily Confirmed Count : DailyConfirmed <br>
# - Daily Death Count : DailyDeaths <br>
# - Daily Recovered Count : DailyRecovered' <br>
# - Daily Testing Count : DailyTesting' <br>
# - ActiveCases to Active
#
# Creating the dataframe for the current date (corresponding day) cases (starting from day "1" which is the day on which the country reached its first 10 or more COVID19 cases) for all countries by only taking the last value for their data (i.e. the data for the current date (corresponding day) for them)
#
# Since not all countries have same number of days being affected by COVID-19 till the present date but the number of rows/days in our MergedData for each country are equal to maximumum number of days any country has (in our case China). So what happens is after the current date (corresponding day for the country) there are null values for the following days. Like for Australia if the current date is the 155th day since the first 10 COVID19 cases were registered but on current date China is as far as 186th day since first 10 COVID19 cases were registered, so in that case Australia after 155th day has null values for the confirmed, deaths, recovered and testing for all remaining days till 175.<br> <br>
#
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid9.gif" width="550", height ="900" /></div> <br> <br>
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid10.gif" width="550", height ="900" /></div> <br> <br>
#
#
# But to get the present date(corresponding day) data for example data for 155th day for "Australia" and 186th day for China above and similary for all other countries for their respective current day, we drop the rows for which "CumConfirmed" has null values (thereby dropping "DailyConfirmed", "CumDeaths", "DailyDeaths", "CumRecovered", "DailyRecovered", "CumTesting" , "DailyTesting" and DailyTesting_per_1000" columns). Because then last tail value for every country gives their present date(corresponding day) data.
#
# So we drop null values from "CumConfirmed" columns and thereby all corresponding rows and get the following output <br> <br>
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid11.gif" width="550", height ="900" /></div> <br> <br>
#
# Let's call this dataframe as "df_tails"
#
# We define one more derived variable through columns in df_tails. The derived column is Testing_per_Confirmed which gives the Testing to confirmed ratio for the cuurent date (corresponding day) for the country.
#
# - <font color = blue> Testing_per_Confirmed = CumTesting/CumConfirmed </font>

# %% [markdown]
# #### Final Datasets:
#
# <b> MergedData </b> <br> <br>
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/fig16.png" width="800" /></div> <br> <br>
#
# <b> df_tails </b> <br> <br>
# <div style="text-align: left"><img src="https://raw.githubusercontent.com/namitachhibba/Figures-and-gifs/master/vid12.gif" width="550", height ="900" /></div> <br> <br>
